# %%
fruit_list= { 'orange': (8,7,12) , 'coconut': (10,20,30), 'dragonfruit': (6,12,14)} 
num = int(input('Please enter an integer number: '))
keylist = list(fruit_list.keys())
vallist = list(fruit_list.values())
print(vallist)
numkey = vallist.index(num)
print(keylist[numkey])
for value in  fruit_list.values():
    if (value==num):
        print('yes')
        break
    else:
        print('no')
        break
# Out:
# Please enter an integer number: 10
# [(8, 7, 12), (10, 20, 30), (6, 12, 14)]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-6ede2d9f5d07> in <module>
#       4 vallist = list(fruit_list.values())
#       5 print(vallist)
# ----> 6 numkey = vallist.index(num)
#       7 print(keylist[numkey])
#       8 for value in  fruit_list.values():
#
# ValueError: 10 is not in list
